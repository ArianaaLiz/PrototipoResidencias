# %%
# Importar librerías
import pandas as pd
import os

# Establecer directorio de trabajo
os.chdir(r'/Users/adrianamedrano/Documents/Ariana/Residencias/PrototipoResidencias/DataSets')

# Leer archivos CSV
df_clird = pd.read_csv('Clird.txt', encoding='latin1')
df_clir = pd.read_csv('Clir.txt', encoding='latin1')
df_clientes = pd.read_csv('Clientes.txt', encoding="latin1")

# Mergear dataframes por campo Numrem 
df_clird = pd.merge(df_clird, df_clir[['Numrem','Fecrem','Estado', 'Clacli']],
                    on='Numrem',
                    how='left',
                    suffixes=('', '_Clir'))

# Mergear con el dataframe df_clientes por campo Clacli
df_clird = pd.merge(df_clird, df_clientes[['Clacli', 'Clatipcli']],
                    left_on='Clacli',
                    right_on='Clacli',
                    how='left')

# Filtrar por Estado = 'yes'
df_clird = df_clird[df_clird['Estado_Clir'] == 'yes'][['Claart', 'Fecrem', 'Cant', 'Clacli', 'Clatipcli']]
df_clird
# Out:
#            Claart    Fecrem  Cant   Clacli  Clatipcli
# 0       08ACOMAVT  31/08/20   1.0  MRS2043          0
# 1        08ACOMBI  31/08/20   1.0  MRS2043          0
# 2      08ACOMM114  31/08/20   1.0  MRS2043          0
# 3       08ACOMRED  31/08/20   1.0  MRS2043          0
# 4       08TUBA114  31/08/20   1.0  MRS2043          0
# ...           ...       ...   ...      ...        ...
# 91895  03PP10020Z  13/11/23   6.2   PUBGEN          0
# 91896    04HBISL3  13/11/23   2.0   PUBGEN          0
# 91897   04CHPFANL  13/11/23   1.0   PUBGEN          0
# 91898  01CEMCAZ50  13/11/23   2.0   PUBGEN          0
# 91899   03SOL1812  13/11/23   2.0   PUBGEN          0
#
# [88485 rows x 5 columns]

# %%
condicion = df_clird['Clatipcli'].isin([4, 5, 8])
registros_eliminados = df_clird[condicion].copy()
df_clird = df_clird[~condicion]  
print("Registros eliminados:")
registros_eliminados
# Out:
# Registros eliminados:
#            Claart    Fecrem  Cant     Clacli  Clatipcli
# 3258   01CEMCAZ50  12/02/18   5.0     PEJE72          4
# 7323      06AEROB  27/07/18   1.0    RAGA820          8
# 7739      01ALREC  15/08/18  10.0   MOST1118          8
# 7740     06CLA212  15/08/18   5.0   MOST1118          8
# 7921     06CEPI12  21/08/18   1.0    MRS1896          8
# 7922    06IMPTR19  21/08/18   1.0    MRS1896          8
# 7923     06MAGPRO  21/08/18   1.0    MRS1896          8
# 8850    04HSI2178  24/09/18   2.0     PEJE72          4
# 10282  04HPPB1434  08/11/18  50.0      SIG72          4
# 14513     0614451  26/03/19   1.0      PET04          4
# 14514     06ESP10  26/03/19   1.0      PET04          4
# 14515    06ESPONJ  26/03/19   1.0      PET04          4
# 18079     06CONCR  10/07/19   1.0    MRS1896          8
# 20707  01CEMCAZ50  23/09/19   6.0   MRSZI013          8
# 23670  01CEMCAZ50  16/12/19   8.0    MRS1850          8
# 23671    01ARM124  16/12/19   9.0    MRS1850          8
# 44369   06CLAC212  09/02/21  20.0  MRSZI1234          8
# 44447   05COPPVC4  10/02/21   6.0   MRSZI026          8
# 44448   05TEEPVC4  10/02/21   3.0   MRSZI026          8
# 44449     0644323  10/02/21   1.0   MRSZI026          8
# 44450     0644302  10/02/21   1.0   MRSZI026          8
# 44451  06GRAPG114  10/02/21  10.0   MRSZI026          8
# 49190  06MAG10175  27/05/21  90.0     MRS311          8
# 49191     0615901  27/05/21   2.0     MRS311          8
# 54318        01ES  20/09/21  20.0     MRS311          8
# 55406        01ES  15/10/21  37.0     MRS311          8
# 62698     0549365  28/03/22   1.0   MOST1118          8
# 62699   05COPCP12  28/03/22   8.0   MOST1118          8
# 63046    05JUEGHH  04/04/22   1.0   MRSZI013          8
# 63048   01EST1520  04/04/22  50.0  MRSZI1234          8
# 74396    01ARM204  03/12/22   5.0   MRSZI013          8
# 74397     01VAR38  03/12/22   2.0   MRSZI013          8
# 74398     01ALREC  03/12/22   1.0   MRSZI013          8
# 80464        01ES  25/03/23   5.0  MRSZI1234          8
# 87115     0610252  18/08/23   1.0   LESA7302          8
# 87116     0611582  18/08/23   1.0   LESA7302          8
# 87117     0618100  18/08/23   2.0   LESA7302          8

# %%
print("\nRegistros restantes en df_clifad:")
df_clird
# Out:
# Registros restantes en df_clifad:
#            Claart    Fecrem  Cant   Clacli  Clatipcli
# 0       08ACOMAVT  31/08/20   1.0  MRS2043          0
# 1        08ACOMBI  31/08/20   1.0  MRS2043          0
# 2      08ACOMM114  31/08/20   1.0  MRS2043          0
# 3       08ACOMRED  31/08/20   1.0  MRS2043          0
# 4       08TUBA114  31/08/20   1.0  MRS2043          0
# ...           ...       ...   ...      ...        ...
# 91895  03PP10020Z  13/11/23   6.2   PUBGEN          0
# 91896    04HBISL3  13/11/23   2.0   PUBGEN          0
# 91897   04CHPFANL  13/11/23   1.0   PUBGEN          0
# 91898  01CEMCAZ50  13/11/23   2.0   PUBGEN          0
# 91899   03SOL1812  13/11/23   2.0   PUBGEN          0
#
# [88448 rows x 5 columns]

# %%
# Guardar dataframe 
df_clird.to_csv(r'/Users/adrianamedrano/Documents/Ariana/Residencias/PrototipoResidencias/DataSets_Codigo/Mer_Clird.txt', index=False, encoding="latin1")

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=f6e53d21-17bd-40b4-9b5d-0d63804f9374' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
