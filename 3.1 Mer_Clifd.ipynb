# %%
# Importar librerías
import pandas as pd
import os

# Establecer directorio de trabajo  
os.chdir(r'/Users/adrianamedrano/Documents/Ariana/Residencias/PrototipoResidencias/DataSets')

# Leer archivos CSV  
df_clifd = pd.read_csv('Clifd.txt', encoding="latin1")
df_clif = pd.read_csv("Clif.txt", encoding="latin1", dtype={20: str, 34: str, 35: str, 37: str, 39: str})
df_clientes = pd.read_csv('Clientes.txt', encoding="latin1")

# Mergear dataframes por campo Numfac
df_clifd = pd.merge(df_clifd, df_clif[['Numfac', 'Fecfac', 'Estado', 'Clacho', 'Clacli']],
                    on='Numfac',
                    how='left', 
                    suffixes=('', '_Clif'))

# Mergear con el dataframe df_clientes por campo Clacli
df_clifd = pd.merge(df_clifd, df_clientes[['Clacli', 'Clatipcli']],
                    left_on='Clacli',
                    right_on='Clacli',
                    how='left')

# Filtrar por Estado = 'yes' y Clacho nulo
df_clifd = df_clifd[(df_clifd['Estado_Clif'] == 'yes') & (df_clifd['Clacho'].isnull())][['Claart', 'Fecfac', 'Cant', 'Clacli', 'Clatipcli']]
df_clifd
# Out:
#             Claart    Fecfac   Cant   Clacli  Clatipcli
# 0       01CEMCAZ50  01/09/20   40.0    PSP14        0.0
# 1       01CEMCAZ50  31/08/20  100.0   RELP55        1.0
# 6       01CEMCAZ50  31/08/20  100.0   RELP55        1.0
# 7          01SON40  31/08/20   18.0   RELP55        1.0
# 8            GTRAS  31/08/20    1.0   RELP55        1.0
# ...            ...       ...    ...      ...        ...
# 301370       GTRAS  13/11/23    3.0  MRS2043        0.0
# 301371     01VAR38  13/11/23   20.0    NMA15        0.0
# 301372   04HDDC412  13/11/23    4.0    NMA15        0.0
# 301373     01ALREC  13/11/23   10.0    NMA15        0.0
# 301374     01BLO15  13/11/23  500.0    NMA15        0.0
#
# [283318 rows x 5 columns]

# %%
condicion = df_clifd['Clatipcli'].isin([4, 5, 8])
registros_eliminados = df_clifd[condicion].copy()
df_clifd = df_clifd[~condicion] 
print("Registros eliminados:")
registros_eliminados
# Out:
# Registros eliminados:
#             Claart    Fecfac   Cant    Clacli  Clatipcli
# 10          06CLA3  31/08/20    6.0     FAL03        4.0
# 11       01MALSOL6  31/08/20  100.0     FAL03        4.0
# 12        01CEMBIG  31/08/20    4.0   BLO1703        8.0
# 40        01COMB34  31/08/20   14.0  MRSZI013        8.0
# 41          01ARE4  31/08/20    8.0  MRSZI013        8.0
# ...            ...       ...    ...       ...        ...
# 301094  01CEMCAZ50  13/11/23  200.0    ROLA75        8.0
# 301268    01ARM204  13/11/23    2.0    MERG68        4.0
# 301269   01MALSOL6  13/11/23    5.0    MERG68        4.0
# 301270  01CEMCAZ50  13/11/23    2.0    MERG68        4.0
# 301308       01YEM  13/11/23   50.0    MARG73        8.0
#
# [32020 rows x 5 columns]

# %%
df_clifd
# Out:
#             Claart    Fecfac   Cant   Clacli  Clatipcli
# 0       01CEMCAZ50  01/09/20   40.0    PSP14        0.0
# 1       01CEMCAZ50  31/08/20  100.0   RELP55        1.0
# 6       01CEMCAZ50  31/08/20  100.0   RELP55        1.0
# 7          01SON40  31/08/20   18.0   RELP55        1.0
# 8            GTRAS  31/08/20    1.0   RELP55        1.0
# ...            ...       ...    ...      ...        ...
# 301370       GTRAS  13/11/23    3.0  MRS2043        0.0
# 301371     01VAR38  13/11/23   20.0    NMA15        0.0
# 301372   04HDDC412  13/11/23    4.0    NMA15        0.0
# 301373     01ALREC  13/11/23   10.0    NMA15        0.0
# 301374     01BLO15  13/11/23  500.0    NMA15        0.0
#
# [251298 rows x 5 columns]

# %%
# Guardar dataframe 
df_clifd.to_csv(r'/Users/adrianamedrano/Documents/Ariana/Residencias/PrototipoResidencias/DataSets_Codigo/Mer_Clifd.txt', index=False, encoding="latin1")

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=f6e53d21-17bd-40b4-9b5d-0d63804f9374' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
